# %%
import requests
import pandas as pd
from io import StringIO
import json

import os
import time
start_time = time.time()

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

from collections import defaultdict 

import sys
from importlib import reload

pd.set_option('display.min_rows', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
pip install pipenv
# Out:
# Collecting pipenv
#   Downloading pipenv-2023.2.4-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: certifi in c:\users\zhenhai\anaconda3\lib\site-packages (from pipenv) (2019.11.28)
# Collecting virtualenv-clone>=0.2.5
#   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
# Collecting virtualenv
#   Downloading virtualenv-20.19.0-py3-none-any.whl (8.7 MB)
# Requirement already satisfied: setuptools>=36.2.1 in c:\users\zhenhai\anaconda3\lib\site-packages (from pipenv) (45.2.0.post20200210)
# Collecting platformdirs<4,>=2.4
#   Downloading platformdirs-3.0.0-py3-none-any.whl (14 kB)
# Collecting filelock<4,>=3.4.1
#   Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# Collecting importlib-metadata>=4.8.3; python_version < "3.8"
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting typing-extensions>=4.4; python_version < "3.8"
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\zhenhai\anaconda3\lib\site-packages (from importlib-metadata>=4.8.3; python_version < "3.8"->virtualenv->pipenv) (2.2.0)
# Installing collected packages: virtualenv-clone, typing-extensions, platformdirs, filelock, distlib, importlib-metadata, virtualenv, pipenv
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.0.12
#     Uninstalling filelock-3.0.12:
#       Successfully uninstalled filelock-3.0.12
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 1.5.0
#     Uninstalling importlib-metadata-1.5.0:
#       Successfully uninstalled importlib-metadata-1.5.0
# Successfully installed distlib-0.3.6 filelock-3.9.0 importlib-metadata-6.0.0 pipenv-2023.2.4 platformdirs-3.0.0 typing-extensions-4.4.0 virtualenv-20.19.0 virtualenv-clone-0.5.7
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: trie 2.0.0a5 has requirement typing-extensions<4,>=3.7.4, but you'll have typing-extensions 4.4.0 which is incompatible.

# %%
kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk

# %%
from web3 import Web3
import subprocess, os, sys, json


def scanContractInPeriod(web3, startBlockNumber, endBlockNumber):
    for i in range(startBlockNumber, endBlockNumber):
        print('Scaning block ', i, ' ...')
        block = web3.eth.getBlock(i)
        transactions = block.transactions
        for transaction in transactions:
            receipt = web3.eth.getTransactionReceipt(transaction)
            print(transaction)
            # check if contract deployed successfully
            # if receipt.contractAddress and web3.toHex(web3.eth.getCode(receipt.contractAddress)) == '0x':
            if receipt.contractAddress:
                contract = receipt.contractAddress + '\n'
                with open('ContractList.txt', 'a') as f:
                    f.write(contract)
    with open('ContractList.txt', 'a') as f:
        end = '... till block ' + str(i) + ' \n'
        f.write(end)

def auditContractByAddress(address):
    location = 'reports/'+address+'.md'
    if not os.path.isfile(location):
        with open(location, 'w') as f:
            subprocess.call(["myth", "-xia", address, "-o", "markdown", "--max-depth", "12", "-l"], stdout=f, stderr=f)
    else:
        print('audit exists ...')

def auditAllContractFound():
    with open('ContractList.txt', 'r') as f:
        for line in f:
            print('Auditing ' + line.rstrip('\n') + ' contract \n...')
            auditContractByAddress(line.rstrip('\n'))

if __name__ == "__main__":
    if len(sys.argv) == 1:
        print("Use argument -a to audit all contracts found, and -s to scan all contract till lastest block!")
    elif sys.argv[1] == '-a':
        auditAllContractFound()
    elif sys.argv[1] == '-s':
        #web3 = Web3(Web3.HTTPProvider("https://mainnet.infura.io/v3/f8fd67ea548840fcacb384f39e6f579d"))
        web3 = Web3(Web3.HTTPProvider("https://mainnet.infura.io/v3/f8fd67ea548840fcacb384f39e6f579d"))
        endBlockNumber = web3.eth.blockNumber
        startBlockNumber = web3.eth.blockNumber - 10
        scanContractInPeriod(web3, startBlockNumber, endBlockNumber)
    else:
        print("Use argument -a to audit all contracts found, and -s to scan all contract till lastest block!")
# Out:
# Use argument -a to audit all contracts found, and -s to scan all contract till lastest block!

# %%
#$ export WEB3_INFURA_PROJECT_ID = '7188fbb9e7aa48d2af85b49c976ab04b'

# Set environment variables
os.environ['WEB3_INFURA_PROJECT_ID'] = '7188fbb9e7aa48d2af85b49c976ab04b'

from web3.auto.infura import w3

w3.isConnected()
# Out:
# True

# %%
web3 = Web3(Web3.HTTPProvider("https://mainnet.infura.io/v3/7188fbb9e7aa48d2af85b49c976ab04b"))
startBlockNumber = web3.eth.blockNumber - 1
print('block number \n')
print(web3.eth.blockNumber)
endBlockNumber = web3.eth.blockNumber
#endBlockNumber = endBlockNumber
scanContractInPeriod(web3, startBlockNumber, endBlockNumber)
# Out:
# block number
#
# 14386624
# Scaning block  14386623  ...

# %%
block = web3.eth.getBlock(14386601)
transactions = block.transactions
transactions
# Out:
# [HexBytes('0xa84e0f245418a42a4f45a803cbb908c1637b946bbee7a3e7944dbbb5f29a26fe'),
#  HexBytes('0xe870d52c6a96deb960b5e6d398fa4424849ed8b31c9fd2d87fc8b746c6184051'),
#  HexBytes('0x3d1b39c7422981a82bcd1a8152bfc86be3e2825637773828f1e43056586b794f'),
#  HexBytes('0x6cf2db763826639b0f0ceadf69f9ea926625c080ab3cb32cf2ea9fd4809ff8f4'),
#  HexBytes('0xb1b4201df02554dff17fd11bdfb46bdf7ba66dcf158927cf4a40910b8b7522d5'),
#  HexBytes('0x78cba89475b7768730cd54c75c292f97a43796dfa62b7d4a2e212101f057ef66'),
#  HexBytes('0x66d3881abd63b4e72c5e4d0717e7830da521369b1782ca4fd4812819074d09e5'),
#  HexBytes('0xd63a2b2719e6c9229e921f06373ffd868d4ff2aa8193c277b9ffcf616019b59b'),
#  HexBytes('0xdd86cd37c6fd67595d18fc5adb6d1cadfc4195b2a43be05f2062d45eb28d0f7b'),
#  HexBytes('0xb8f3a2b8fb4456d66aa4ea94bdeee152c79a299db8bf59bb397a282c570012c1'),
#  HexBytes('0x64230e4333dc5b7d5ba3a5c514d8374703a00f6c1ec5aa799ecd323b64e6ef65'),
#  HexBytes('0x37ff6b5a621098ab9603cdd22c9b20e8d13fba553271702838bdeb4c0bedd4e4'),
#  HexBytes('0xdf39f92a40b32ef7540fc4f6552bb5304b6e3f569d3750414db14171c831b43b'),
#  HexBytes('0x396c864d569c89d88a8dc034789534c377a06aaab5179fc1ce035c7cbcfc89f4'),
#  HexBytes('0x88fd977b346c2792a2acce60d9b99dd260885ccf3ba3d40d9fb4b8440ab1ef6a'),
#  HexBytes('0xa66fe4dcbe3461ac7cc1b64294b30db654877836f8012107e0a9beaff1fff03b'),
#  HexBytes('0x3934790af8609288ed92281c7c2b36f38e50b1345776dc6298c9aa07e305b63b'),
#  HexBytes('0x21013e691c707a94de9e980e0dc11da4f3f12d72f26f2c59355546f16ebe2f09'),
#  HexBytes('0xf533f2132484c34db84a64cf218e1d94d421a42659bafad8d3ec1a332c0ed6ed'),
#  HexBytes('0x63f89c69f8acdf11c46341e3549915c53f519fcba489fb28904dec6142e59170'),
#  HexBytes('0x0afd12902d038e782e0fb34b11aa1aa84dd9542ce1c264fa30a6e245a4f213c7'),
#  HexBytes('0x204c7d67d8bed73276c85db41d7dd92bdb6e81151311e21a07e59eb7febcd04b'),
#  HexBytes('0x7a03c750642f842bd4c4de5e78e90a2316209548e6acdcd31028a51368a37955'),
#  HexBytes('0x8efacb01641a89ecd55df5c5e8f99f9c41b22e7a3ebf95b510cd1de7a56a3030'),
#  HexBytes('0x904237ba359833c69f368d69d02140ef179b1e2b9ec17ef472187d802c1198e8'),
#  HexBytes('0x4660ae8b679b4be6ae8476dcea85b2bdec2373690c1f1389c197d3112588af4e'),
#  HexBytes('0x1fdd94287c0b56287358be21e649569bc8f41f3f1bb1e2082d11f1b1b085d74e'),
#  HexBytes('0xdf69245d7f216ae82d6b7a7f3c6c72b7a0d199fbbda766ca063163dc7de457a3'),
#  HexBytes('0x75f25fd2d7b582c298b6c0ced6b8a62441c2433749e41c46c75e9f7f2b1e512f'),
#  HexBytes('0x761318c7bb554ac36255958b12e6d62c7725ad1126ce3d1e4bba4b5e717d60b9'),
#  HexBytes('0xafbe73bde58a16d0c7119deacd700c08258b2a08cea5c2bf0a5f74d004fde891'),
#  HexBytes('0x4ecf04504ee7625513383e9fa2eb5c8fb9ec7258f1ae50feb7ec9153f6d4bd1c'),
#  HexBytes('0xaa6950b8bda574d7a4dee15136204d93563664fd96e37f7094b1b18c7e51da13'),
#  HexBytes('0xa359c6b36f261ab50c09e1d0ef6707740b44196b871fa26be142e936ff567607'),
#  HexBytes('0xb889435810ee9aca108f9f0c071d369945c74871e5c9b2a379f69e00ab5a9546'),
#  HexBytes('0x1cb56ce190ac8a293859788fd3fc156101fe8656676525c41c018626d7117ee7'),
#  HexBytes('0xe1eb39cd9f277ce932db7552b97faa85f82fb0a0f6068581ea9f4e395fe98f66'),
#  HexBytes('0x134cb3e6d32b3e4c701cad455078d688e28de8847b462403c3500ce178dbe938'),
#  HexBytes('0xf484d8b768ef90fb369b3e768c7c2fec506cf7b4d0261a57662e4bd69f7a5774'),
#  HexBytes('0x0285fbdfc36c5defd5f68184cd9f120e12a52f3e18506137ebdc71e605c95fed'),
#  HexBytes('0xd6ed15d94a268180c61cb6ea97b014ca60bd9a4e80d32899ae15ef33f682d4ff'),
#  HexBytes('0xf696609a9b53fed2d209cbc13bd3f349efebb4467511791b48c150dec62d5c5f'),
#  HexBytes('0x8de893efdc09203d7acd8f44987eea41032d469cac0e98ef6a14e1f4a65c3462'),
#  HexBytes('0x187e9cebe3a43e29d4309174d9df36587b57e78f0652f3caf92bc25a9c48f069'),
#  HexBytes('0x1723d2b65d3e47bd8a909e055a175a6c42b523cca2fbe42fa0acd964658aac35'),
#  HexBytes('0x08de64cfecd31c9ac8a5410ae6057a2205794c3ab9deb7a39963e2e4e18b366c'),
#  HexBytes('0x9cd34038684a325d997f1cf3f2fbd4572fba3e1877b57a414b41638b6046ca6e'),
#  HexBytes('0x628ab4aea198f653f9977b40b088de3c08f9be498af45637c794116b3ec15d20'),
#  HexBytes('0x20869affc2609a308590ecdba69c37623372aeefd3432870a38d9e953000c40e'),
#  HexBytes('0xa90e51e97c48b87ef2377af74736a282d2f394af81f8e12ea33c154540cdc508'),
#  HexBytes('0xa2cdccf6447b5c5073bf8335f0fc111d9f71788ae868d8d3c3f66ea391507300'),
#  HexBytes('0x07b02d0a2887732820150f2e73e21967f179cac371d63ec1c64703ebfd78f597'),
#  HexBytes('0x67620500853c5715515bbcf928ebecaf7ffe91728615f22bb362a1f1fd2fc9e0'),
#  HexBytes('0x51f9a873520a1d0a697b9982175a5b350bf7decd26d94a0f86fda062f231cccb'),
#  HexBytes('0xbd286de77f9a7acc960c7fda2ae853a410acdcf56f331fe166e40b3a63f3cb55'),
#  HexBytes('0x86e33b2e20a6a820eb5e5fb6a5ce2f6480d5509087b8692898ca9d2def8ada74'),
#  HexBytes('0x4238ba9028f9a35c3392bc71477e5e6845f517f0913c60dfa8666ce382c8d32a'),
#  HexBytes('0xf4ed9c15e0fc8266dff3484e1c66bb76a49094765de4a5f39488b7b6a7363a51'),
#  HexBytes('0xb4bd1c58729942e5ef2f2322080864b526d2f036f918b6ae8970a27376a94100'),
#  HexBytes('0xf3940466a86deb1c90180cca83966eac23083c55fe9f368a255e56af01b3bea9'),
#  HexBytes('0xff34b1d09f71d42f61d327b2e84f9f1411aa5c7301724f3738313ea46fe7e91d'),
#  HexBytes('0xf77dd320be481e6d8849659813421213eb686e3645cf45ae84e0028843cc9b5a'),
#  HexBytes('0x48da4be69845941a0b50aee94deddfa6496b355a3d75a4f2dd992f56fd3290d6'),
#  HexBytes('0x90c82db7695d8b6b735600ba58ec8b4fc32647e8b6d31b01e85644071f191437'),
#  HexBytes('0xbad00aa78d155c10c135bb1693e58428e3a246e749a4e6c19cdd620e6ccc8d67'),
#  HexBytes('0x287deb08bcc02ee81a603b69ff8e3f2763877026dcd3fd89818bdcae715b6747'),
#  HexBytes('0x6da67861e9d06718b558d96e3ec0cc3208bba24dbc87277fbb4d84b17349c485'),
#  HexBytes('0x29726311000e139e81a26938d7af87a5f33c3a4abe18444f3c0190b0f27087cf'),
#  HexBytes('0xcfd7ddbcdc59f7995f7108317538627d8423c978ab3e0c0e88421665218ce9de'),
#  HexBytes('0x7feed9f730cab6a06089b2b06a76c4dea975c455f528d2c64ba6f9bdb761eb54'),
#  HexBytes('0x3dd94d7802f3fc43fe4efd514f8516cc064cb10766a39471f6473ad774d09781'),
#  HexBytes('0xf2ac566f08e0c74c41bf9a0f82ad14249c63d7edb66c8617572b7f6adabc3fb3'),
#  HexBytes('0x6f47f0bdd97caf3e87f3afaa40b16a42794b873a4958e8553b0aa6a7ab325778'),
#  HexBytes('0x8b082b20817255f5bb88203a8742afe0441ce7364924adfdad577f57e8d0b496'),
#  HexBytes('0x59f389d58cf3386814c55cf038e1144243b3f902e4fc0cfaebce9cb3d98dc0fc'),
#  HexBytes('0xcda86accf7f057b6ecb452c141512a114cb3a6e31d98950abab657f0406fbe86'),
#  HexBytes('0x317f1d711fc051f2ae9222d64a760744a6be2528803b433990923ac994bd2882'),
#  HexBytes('0xaed1db6880da94bfb54377be676bfe5057547437cd4a873e2e2fb65556cbe619'),
#  HexBytes('0x8c40836fc423a705a893198d718da633c03d32c9fe1fc10e2d7de36356e34446'),
#  HexBytes('0x2c70fa398ac8fb1297f85adaf327bade956062686608e650df1c28ae7be0b683'),
#  HexBytes('0xa168fd632eb92673ec43ceb3b626d258c03ace14292beebb74e47b5b2f74e61f'),
#  HexBytes('0x6d9680f06cc8ce69c45c347577a2325e3cd3c9d8efc48f7eabfa65c09333a7eb'),
#  HexBytes('0x48ba3cf60b18ff7502423f8def3dab3437345cf6c7ab01c0bcfdd4f7023264b4'),
#  HexBytes('0xa1fc36e6339c14fb823f93ebfebcf7ac3cd119744676608e9afadd51434e0ac6'),
#  HexBytes('0xd7738300ca451df8a2dd8c77257152b9f8ea0725a7176a4b1251962b857af3dc'),
#  HexBytes('0x1808b09eb18dca8d41b3008c7f2ce558196db6e09926b05e82a4a61b80309116'),
#  HexBytes('0xa4c8074bc29e116564b8becbd5d849f5dbf6c538ad73ad32947856eb3bcc540d'),
#  HexBytes('0xa2966262632cce49ef794dd3e827c04a456a585a04ba337d869f8deda82aa2af'),
#  HexBytes('0x471f78a22fbc5b1c9c8ce5fb93fc5ea0b26c6533a43b248c5505b3a7a8e3b925'),
#  HexBytes('0x673642c7b08ac612586eeecfbc74f0b046730717c11194987849c6f4400bf281'),
#  HexBytes('0x89ee76f30ba0c6ace96fb1e18290d134d300c86af25c04b207e53916d44177fa'),
#  HexBytes('0x3463642be741ad4285e1ab6ceba96729575b79ed48cadce59685dd7c004582ff'),
#  HexBytes('0xe8c71920d0c4e021da2cf56cd8da9eb4613303e2145664253b5b6e160f8e1498'),
#  HexBytes('0x33f618cdc84c230d69c4ed707c8b4a8256aceb474ad953ba688076118a7ec40f'),
#  HexBytes('0xd844294df762cc88ae9b01b7b7318f211772c5942845da767e4ff965c3b3ce73'),
#  HexBytes('0xf88c1dbc199d4555efefa3f0fa5e8f7d84a4278c8858f374b5f89a5ca18d69dd'),
#  HexBytes('0x9315b353c0174e3be76fbf2539162a17cc584d40ba1b5e1f1c03409ce545adc7'),
#  HexBytes('0xe272e192a99e5d663bd5d3f226916d5910ce8b2d2ad5580042a167a0792a0e7c'),
#  HexBytes('0x9876fecb4fd4ddae042579b8194c17a32d89465a8316d73f2fe57bee791dfef0'),
#  HexBytes('0xdb8c2fa75661a7d8b2624518caec597ad80cb84eb3fd906be35652ebceb8bdff'),
#  HexBytes('0x38df42471e675b694243afd7ddca59fcd3bc76dd3dccc4e04270338d7c79e962'),
#  HexBytes('0x1f9a757cfd6e443b69acdb5efd7288a70973da479a5ece78061071ae5c3aecdc'),
#  HexBytes('0xb033be7e598aafdaa67f91129fc4959c2fd96ed92a959833cd253669adf6d623')]

# %%
web3.eth.blockNumber
# Out:
# 14386601
